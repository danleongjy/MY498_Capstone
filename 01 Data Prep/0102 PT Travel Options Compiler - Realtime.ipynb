# %%
import csv
import requests
import json
import time as tm
import sqlite3
import traceback
import sys
from math import cos, asin, sqrt
from multiprocessing.dummy import Pool as ThreadPool
import os
import datetime
from IPython.display import clear_output
import pickle
import pandas as pd
import random

from tfl_journeyplanner_api_tools import *

# %%
# Read in origin longlats: pop-weighted MSOA centroids
orig_coords = []
with open('PopWeightedCentroids2011LondonMSOA_coords.csv', 'r') as inputfile:
    reader = csv.reader(inputfile, delimiter = ',')
    for row in reader:
        orig_coords.append((row[0], row[4], row[5])) # read in longlats coords from csv file into tuples
orig_coords = orig_coords[1:]

# Read in destination longlats: jobs-weighted MSOA centroids
dest_coords = []
with open('JobsWeightedCentroids2011LondonMSOA_coords.csv', 'r') as inputfile:
    reader = csv.reader(inputfile, delimiter = ',')
    for row in reader:
        dest_coords.append((row[0], row[1], row[2])) # read in longlats coords from csv file into tuples
dest_coords = dest_coords[1:]

odpairs = GenerateODPairs(orig_coords[:], dest_coords[:]) # specify how many OD pairs to generate here
print(len(orig_coords), len(dest_coords)) # checking data import was successful
print(len(odpairs), "pairs generated. First 10:", odpairs[:10])
# Out:
# 983 983
# 966289 pairs generated. First 10: [(('E02006854', '-0.025046237', '51.50164399'), ('E02000001', '-0.091155997', '51.51475914')), (('E02006854', '-0.025046237', '51.50164399'), ('E02000002', '0.136596432', '51.58623085')), (('E02006854', '-0.025046237', '51.50164399'), ('E02000003', '0.138810779', '51.5705831')), (('E02006854', '-0.025046237', '51.50164399'), ('E02000004', '0.17624198', '51.56078086')), (('E02006854', '-0.025046237', '51.50164399'), ('E02000005', '0.144375564', '51.56175313')), (('E02006854', '-0.025046237', '51.50164399'), ('E02000007', '0.154249648', '51.55985824')), (('E02006854', '-0.025046237', '51.50164399'), ('E02000008', '0.138580433', '51.55208708')), (('E02006854', '-0.025046237', '51.50164399'), ('E02000009', '0.118662175', '51.55239182')), (('E02006854', '-0.025046237', '51.50164399'), ('E02000010', '0.150976445', '51.5482683')), (('E02006854', '-0.025046237', '51.50164399'), ('E02000011', '0.162473217', '51.54805375'))]

# %%
# set up currentpairs
target_msoas = ['E02000384','E02000455','E02000558','E02000649','E02000664','E02000779','E02000001'] # 6 cluster centroids and City
currentpairs = [odpair for odpair in odpairs if odpair[1][0] in target_msoas]
random.shuffle(currentpairs) # randomise order to randomise API call time per pair
print(len(currentpairs))
# Out:
# 6881

# %%
# set up batchsettings
batchsettings = {'processingstarttime': datetime.datetime(2019,4,25,6,0), # 0600 or 1100
                 'processingendtime': datetime.datetime(2019,4,25,8,0), # 0800 or 1300
                 'date': '', #'&date=20190322',
                 'time': '', #'&time=0830',
                 'timeIs': '', #'&timeIs=Arriving',
                 'journeyPreference': '&journeyPreference=leastTime',
                 'useMultiModalCall': '&useMultiModalCall=true'}

# %%
#set up db
db = '20190425_ampeak/traveloptions_to_cityplus6clusters.db'
if not os.path.exists('20190425_ampeak'):
    os.makedirs('20190425_ampeak')
setup_db(db)

# %%
# set up network data
with open('stoplocations.json', 'r') as infile:
    stoplocations = json.load(infile)
stoplist = {}
for stop in stoplocations['features']:
    stoplist[stop['properties']['NAPTAN']] = stop['geometry']['coordinates']
# with open('networkdata', 'rb') as infile:
#     edges, nodes = pickle.load(infile)
edges = {}
nodes = {}
print(len(stoplist), len(edges), len(nodes))
# Out:
# 12838 0 0

# %%
# Execute data collection from API and write to DB
# Multithreaded version
# Auto-looping to reprocess pairs with errors

while len(currentpairs) > 0:
    # Batching of OD pairs into 290s
    startpos = 0
    nbatches = len(currentpairs) // 290 + 1
    initialbatchsize = len(currentpairs) % 290
    processed = set()
    errors = []

    # timed start
    while datetime.datetime.now() < batchsettings['processingstarttime']:
        print('Time is', datetime.datetime.now(), '. Starting processing at', batchsettings['processingstarttime'])
        tm.sleep(10)
        clear_output()

    print("Starting processing:", len(currentpairs), "pairs in", nbatches, "batches.")

    for batch in range(nbatches):
        outputs = []
        starttime = tm.clock()
        pool = ThreadPool(12)

        # multithreaded query the next batch of 290
        outputs.extend(pool.starmap(call_api, [(pair, stoplist, batchsettings) for pair in currentpairs[startpos : (initialbatchsize + batch * 290)]]))
        pool.close()
        pool.join()

        downloadtime = tm.clock() - starttime

        # single-thread write this batch's outputs to db - to avoid schema locks
        for output in outputs:
            for option in output:
                if option[4]:
                    write_to_db(db, option[0][0][0], option[0][1][0], option[1], option[2])
                    write_to_network(edges, nodes, option[3])
                    processed.add(option[0])
                else:
                    errors.append(option[0])

        processingtime = tm.clock() - starttime

        print('Processed batch', batch, 'in', processingtime, 's (', str(downloadtime/processingtime * 100)[:4], '% download time).', 
              len(processed) + len(errors), 'pairs processed altogether with', len(errors), 'errors so far.')

        # update next batch's startpos to be this batch's endpos
        startpos = initialbatchsize + batch * 290

        # check if processing time has expired
        if datetime.datetime.now() > batchsettings['processingendtime']:
            print('Abort - processing time ended at', datetime.datetime.now())
            break

        # if finished this batch in less than 60s, wait until 60s has passed for this batch
        if processingtime < 60:
            print('Waiting', 60 - processingtime, 's before next batch.')
            tm.sleep(60 - processingtime)
    print('Completed.')
    
    # check if processing time has expired
    if datetime.datetime.now() > batchsettings['processingendtime']:
        print('Abort - processing time ended at', datetime.datetime.now())
        break
        
    # if all pairs processed this round produced errors, then break the processing
    if len(errors) == len(currentpairs):
        print('Abort - all pairs processed this batch produced errors.')
        break
    else:
        currentpairs = [pair for pair in currentpairs if pair not in processed]
# Out:
# Starting processing: 6881 pairs in 24 batches.
# Processed batch 0 in 180.14939814417122 s ( 75.1 % download time). 211 pairs processed altogether with 0 errors so far.
# Processed batch 1 in 245.60318816620426 s ( 74.1 % download time). 501 pairs processed altogether with 0 errors so far.
# Processed batch 2 in 244.79697328441648 s ( 74.3 % download time). 791 pairs processed altogether with 0 errors so far.
# Processed batch 3 in 239.6671358102369 s ( 73.7 % download time). 1081 pairs processed altogether with 0 errors so far.
# Processed batch 4 in 262.3663285002442 s ( 76.3 % download time). 1371 pairs processed altogether with 0 errors so far.
# Processed batch 5 in 241.90922811470864 s ( 74.5 % download time). 1661 pairs processed altogether with 0 errors so far.
# Processed batch 6 in 239.6686348320327 s ( 73.2 % download time). 1951 pairs processed altogether with 0 errors so far.
# Processed batch 7 in 225.9253714701165 s ( 72.3 % download time). 2241 pairs processed altogether with 0 errors so far.
# Processed batch 8 in 249.5802158705162 s ( 73.9 % download time). 2531 pairs processed altogether with 0 errors so far.
# Processed batch 9 in 246.7344319333174 s ( 74.9 % download time). 2821 pairs processed altogether with 0 errors so far.
# Processed batch 10 in 237.0129985385247 s ( 73.1 % download time). 3111 pairs processed altogether with 0 errors so far.
# Processed batch 11 in 223.02182314045922 s ( 70.8 % download time). 3401 pairs processed altogether with 0 errors so far.
# Processed batch 12 in 239.75822172210565 s ( 74.3 % download time). 3691 pairs processed altogether with 0 errors so far.
# Processed batch 13 in 232.63285912665333 s ( 72.5 % download time). 3981 pairs processed altogether with 1 errors so far.
# Processed batch 14 in 227.5175527772294 s ( 72.7 % download time). 4271 pairs processed altogether with 1 errors so far.
# Processed batch 15 in 259.11318667002706 s ( 76.8 % download time). 4561 pairs processed altogether with 1 errors so far.
# Processed batch 16 in 219.09612512821332 s ( 70.9 % download time). 4851 pairs processed altogether with 1 errors so far.
# Processed batch 17 in 241.23677262598449 s ( 74.2 % download time). 5141 pairs processed altogether with 1 errors so far.
# Processed batch 18 in 263.1165374246293 s ( 75.8 % download time). 5431 pairs processed altogether with 1 errors so far.
# Processed batch 19 in 224.47634020228543 s ( 72.4 % download time). 5721 pairs processed altogether with 1 errors so far.
# Processed batch 20 in 260.60251289528514 s ( 76.1 % download time). 6011 pairs processed altogether with 1 errors so far.
# Processed batch 21 in 229.62340305823182 s ( 72.6 % download time). 6301 pairs processed altogether with 1 errors so far.
# Processed batch 22 in 231.70568769260444 s ( 73.0 % download time). 6591 pairs processed altogether with 1 errors so far.
# Processed batch 23 in 245.8216784151673 s ( 74.5 % download time). 6881 pairs processed altogether with 2 errors so far.
# Completed.
# Starting processing: 2 pairs in 1 batches.
# Processed batch 0 in 3.3677706331673107 s ( 87.0 % download time). 2 pairs processed altogether with 0 errors so far.
# Waiting 56.63222936683269 s before next batch.
# Completed.

# %%
currentpairs = [pair for pair in currentpairs if pair not in processed]
len(currentpairs)
# Out:
# 0

# %%
with open('20190425_ampeak/networkdata', 'wb') as outfile:
    pickle.dump((edges, nodes), outfile)

# %%
# getting disruption data
results = requests.get('https://api.tfl.gov.uk/Line/Mode/bus%2Ccoach%2Ctube%2Cdlr%2Ctram%2Ctflrail%2Coverground%2Cnational-rail/Disruption')
disruptions = json.loads(results.content)
with open('20190425_ampeak/disruptions', 'wb') as outfile:
    pickle.dump(disruptions, outfile)

# %%
disruptions
# Out:
# [{'$type': 'Tfl.Api.Presentation.Entities.Disruption, Tfl.Api.Presentation.Entities',
#   'category': 'Information',
#   'type': 'specialService',
#   'categoryDescription': 'Information',
#   'description': 'http://www.nationalrail.co.uk/',
#   'additionalInfo': 'Custom',
#   'affectedRoutes': [],
#   'affectedStops': [],
#   'closureText': 'specialService'},
#  {'$type': 'Tfl.Api.Presentation.Entities.Disruption, Tfl.Api.Presentation.Entities',
#   'category': 'Information',
#   'type': 'specialService',
#   'categoryDescription': 'Information',
#   'description': 'http://www.nationalrail.co.uk/',
#   'additionalInfo': 'Custom',
#   'affectedRoutes': [],
#   'affectedStops': [],
#   'closureText': 'specialService'},
#  {'$type': 'Tfl.Api.Presentation.Entities.Disruption, Tfl.Api.Presentation.Entities',
#   'category': 'Information',
#   'type': 'minorDelays',
#   'categoryDescription': 'Information',
#   'description': 'http://www.nationalrail.co.uk/',
#   'additionalInfo': 'Minor delays on some routes',
#   'affectedRoutes': [],
#   'affectedStops': [],
#   'closureText': 'minorDelays'},
#  {'$type': 'Tfl.Api.Presentation.Entities.Disruption, Tfl.Api.Presentation.Entities',
#   'category': 'RealTime',
#   'type': 'routeInfo',
#   'categoryDescription': 'RealTime',
#   'description': 'Docklands Light Railway: Minor Delays Bank and Stratford to Lewisham while we deal with a customer incident at Canary Wharf, GOOD SERVICE on other routes. ',
#   'affectedRoutes': [],
#   'affectedStops': [],
#   'closureText': 'minorDelays'},
#  {'$type': 'Tfl.Api.Presentation.Entities.Disruption, Tfl.Api.Presentation.Entities',
#   'category': 'RealTime',
#   'type': 'routeInfo',
#   'categoryDescription': 'RealTime',
#   'description': 'Docklands Light Railway: Minor Delays Bank and Stratford to Lewisham while we deal with a customer incident at Canary Wharf, GOOD SERVICE on other routes. ',
#   'affectedRoutes': [],
#   'affectedStops': [],
#   'closureText': 'minorDelays'},
#  {'$type': 'Tfl.Api.Presentation.Entities.Disruption, Tfl.Api.Presentation.Entities',
#   'category': 'Information',
#   'type': 'routeInfo',
#   'categoryDescription': 'Information',
#   'description': 'LONDON OVERGROUND: Until further notice, reduced weekday service between Gospel Oak and Barking. A temporary timetable is in place, with four car trains running every 30 minutes. Supplementary bus services will also run. From Tuesday 23 until Friday 26 April, the 2325 train from Gospel Oak to Barking will not operate - the 2248 will be the last service from Gospel Oak.',
#   'additionalInfo': 'For weekday trains see the <a href="http://content.tfl.gov.uk/gospel-oak-to-barking-temporary-timetable-march-2019.pdf">temporary timetable</a>.\xa0<a href="http://content.tfl.gov.uk/gospel-oak-to-barking-supplementary-bus-service-timetable-23-march-2019.pdf">Supplementary buses</a>\xa0will run every 30 minutes. Service J: Hampstead Heath - Gospel Oak – Upper Holloway/Archway - Crouch Hill (Hornsey Road) – Finsbury Park. Service T: Walthamstow Central – Leyton Midland Road - Leytonstone High Road – Leytonstone (Tube).For more information and travel options, visit <a href="https://tfl.gov.uk/modes/london-overground/gospel-oak-to-barking-improvements?cid=gospel-oak-barking-trains">tfl.gov.uk/gospel-oak-barking-trains</a>',
#   'created': '2019-03-13T08:44:00Z',
#   'lastUpdate': '2019-04-23T16:15:00Z',
#   'affectedRoutes': [],
#   'affectedStops': [],
#   'closureText': 'reducedService'},
#  {'$type': 'Tfl.Api.Presentation.Entities.Disruption, Tfl.Api.Presentation.Entities',
#   'category': 'Information',
#   'type': 'routeInfo',
#   'categoryDescription': 'Information',
#   'description': 'LONDON OVERGROUND: Until further notice, reduced weekday service between Gospel Oak and Barking. A temporary timetable is in place, with four car trains running every 30 minutes. Supplementary bus services will also run. From Tuesday 23 until Friday 26 April, the 2325 train from Gospel Oak to Barking will not operate - the 2248 will be the last service from Gospel Oak.',
#   'additionalInfo': 'For weekday trains see the <a href="http://content.tfl.gov.uk/gospel-oak-to-barking-temporary-timetable-march-2019.pdf">temporary timetable</a>.\xa0<a href="http://content.tfl.gov.uk/gospel-oak-to-barking-supplementary-bus-service-timetable-23-march-2019.pdf">Supplementary buses</a>\xa0will run every 30 minutes. Service J: Hampstead Heath - Gospel Oak – Upper Holloway/Archway - Crouch Hill (Hornsey Road) – Finsbury Park. Service T: Walthamstow Central – Leyton Midland Road - Leytonstone High Road – Leytonstone (Tube).For more information and travel options, visit <a href="https://tfl.gov.uk/modes/london-overground/gospel-oak-to-barking-improvements?cid=gospel-oak-barking-trains">tfl.gov.uk/gospel-oak-barking-trains</a>',
#   'created': '2019-03-13T08:44:00Z',
#   'lastUpdate': '2019-04-23T16:15:00Z',
#   'affectedRoutes': [],
#   'affectedStops': [],
#   'closureText': 'reducedService'},
#  {'$type': 'Tfl.Api.Presentation.Entities.Disruption, Tfl.Api.Presentation.Entities',
#   'category': 'Information',
#   'type': 'stopInfo',
#   'categoryDescription': 'Information',
#   'description': "St John's Avenue, stop C on Putney Hill is set down only for Routes 14 37 39 85 93 and 424, to board buses, use stops at Putney Station.",
#   'created': '2018-11-02T15:35:00Z',
#   'lastUpdate': '2018-11-02T15:36:00Z',
#   'affectedRoutes': [],
#   'affectedStops': []},
#  {'$type': 'Tfl.Api.Presentation.Entities.Disruption, Tfl.Api.Presentation.Entities',
#   'category': 'Information',
#   'type': 'stopInfo',
#   'categoryDescription': 'Information',
#   'description': 'MILLENNIUM LEISURE PARK EAST STOP: Alight here for IKEA Greenwich. Buses to North Greenwich, Westcombe Park and Charlton stations stop here.',
#   'created': '2019-02-07T14:10:00Z',
#   'lastUpdate': '2019-02-07T14:12:00Z',
#   'affectedRoutes': [],
#   'affectedStops': []},
#  {'$type': 'Tfl.Api.Presentation.Entities.Disruption, Tfl.Api.Presentation.Entities',
#   'category': 'Information',
#   'type': 'stopInfo',
#   'categoryDescription': 'Information',
#   'description': 'Changes to Routes 55 73 N8 N25 N55 N73 N109 and N136 at Oxford Circus: From Saturday 30 March due to roadworks in Harewood Place, Route 55 73 N8 N25 N55 N73 N109 and N136 buses terminating at Oxford Circus will no longer operate in service to Harewood Place or Holles Street. Buses on Routes 55 73 N8 N25 N55 and will finish journeys at the Great Titchfield Street stop OP in Oxford Street, east of Oxford Circus. Routes N109 and N136 will finish journeys at the Hamleys stop M in Regent Street. There are no changes to stopping arrangements for buses on these routes from Oxford Circus.',
#   'created': '2019-03-28T13:14:00Z',
#   'lastUpdate': '2019-03-28T13:40:00Z',
#   'affectedRoutes': [],
#   'affectedStops': []},
#  {'$type': 'Tfl.Api.Presentation.Entities.Disruption, Tfl.Api.Presentation.Entities',
#   'category': 'Information',
#   'type': 'stopInfo',
#   'categoryDescription': 'Information',
#   'description': 'Changes to Buses in Tottenham Court Road: From Saturday 20 April, southbound Route 14 24 29 73 390 N5 N20 N29 N73 N253 and N279 buses will no longer serve Gower Street and Bloomsbury Street, and stops at University College Hospital, Tollington Place, Chenies Street and Great Russell Street will not be served. New stops are available in the southbound direction on Tottenham Court Road which offer easier interchange with local London Underground stations.',
#   'created': '2019-04-18T17:41:00Z',
#   'lastUpdate': '2019-04-18T17:47:00Z',
#   'affectedRoutes': [],
#   'affectedStops': []},
#  {'$type': 'Tfl.Api.Presentation.Entities.Disruption, Tfl.Api.Presentation.Entities',
#   'category': 'Information',
#   'type': 'stopBlocking',
#   'categoryDescription': 'Information',
#   'description': 'Walthamstow Central Stop AP: Stop AP at Walthamstow Central is closed and services 20, 34, 48, 69, 215, 230, 257, 275, 675, W12, W15, W19, N26, N38 and N73 will no longer serve this stop.',
#   'created': '2019-04-02T16:08:00Z',
#   'lastUpdate': '2019-04-02T16:19:00Z',
#   'affectedRoutes': [],
#   'affectedStops': []},
#  {'$type': 'Tfl.Api.Presentation.Entities.Disruption, Tfl.Api.Presentation.Entities',
#   'category': 'RealTime',
#   'type': 'lineInfo',
#   'categoryDescription': 'RealTime',
#   'description': 'Tamworth Lane - Merton, CR4 1DG. Route 463 subject to diversion due to road being closed (emergency services incident). Buses diverting in both directions via Manor Road.',
#   'created': '2019-04-24T01:23:00Z',
#   'lastUpdate': '2019-04-24T05:56:00Z',
#   'affectedRoutes': [],
#   'affectedStops': []},
#  {'$type': 'Tfl.Api.Presentation.Entities.Disruption, Tfl.Api.Presentation.Entities',
#   'category': 'RealTime',
#   'type': 'lineInfo',
#   'categoryDescription': 'RealTime',
#   'description': 'Well Street - Hackeny, E9. Routes Affected: 26, 277, 388, 425, N26, N277.\r\n\r\nRoute 277 & N277 - From Mare Street left into Morning Lane, ahead Kenton Road, right into Valentine Road, ahead Well Street, left into Cassland Road, and then back to normal line of route.\r\n\r\nRoute 277 & N277 - Southbound from Mare Street at Well Street ahead Mare Street, ahead Cambridge Heath Road, left into Roman Road, right into Grove, and back to normal line of route.\r\n\r\nRoutes 26, 388 & N26 - Eastbound from Mare Street at Well Street ahead Mare Street, right into Morning Lane, ahead Kenton Road, left into Cassland Road, and back to normal line of route. \r\n\r\nRoute 26, N26 - Westbound from Wick Rd, left into Victoria Park Road, left into Mare Street, and back to normal line of route. \r\n\r\nRoute 425 - Northbound from Lauriston Road, left into Victoria Park Road, right into Mare Street, right into Morning Lane, left into Ponsford Street, and back to normal line of route. \r\n\r\nRoute 425 - Southbound from Ponsford Street, right into Morning Lane, left into Mare Street, left into Roman Road, right into Grove Road, and back to normal line of route.',
#   'created': '2019-04-24T01:34:00Z',
#   'lastUpdate': '2019-04-24T05:55:00Z',
#   'affectedRoutes': [],
#   'affectedStops': []},
#  {'$type': 'Tfl.Api.Presentation.Entities.Disruption, Tfl.Api.Presentation.Entities',
#   'category': 'Information',
#   'type': 'lineInfo',
#   'categoryDescription': 'Information',
#   'description': 'Changes to Route 246 from Sunday 3 March: We are reintroducing the seasonal extension between Westerham and Chartwell which operates on Sundays and Bank Holidays (except Good Friday). We plan to operate this extension on Sundays and Bank Holidays from Sunday 3 March until Sunday 3 November 2019.',
#   'created': '2019-02-14T10:30:00Z',
#   'lastUpdate': '2019-03-20T10:05:00Z',
#   'affectedRoutes': [],
#   'affectedStops': []},
#  {'$type': 'Tfl.Api.Presentation.Entities.Disruption, Tfl.Api.Presentation.Entities',
#   'category': 'RealTime',
#   'type': 'lineInfo',
#   'categoryDescription': 'RealTime',
#   'description': 'Route 493 is diverted via Victoria Drive and Augustus Road until late April due to gas works on Wimbledon Park Road. Bus stops between Woodspring Road and Augustus Road are not served. Alternative stops are Wimbledon Tennis Club & Museum or Southmead Primary School.',
#   'created': '2019-03-11T12:46:00Z',
#   'lastUpdate': '2019-04-03T11:50:00Z',
#   'affectedRoutes': [],
#   'affectedStops': []},
#  {'$type': 'Tfl.Api.Presentation.Entities.Disruption, Tfl.Api.Presentation.Entities',
#   'category': 'Information',
#   'type': 'lineInfo',
#   'categoryDescription': 'Information',
#   'description': 'Changes to Route 487 timetable from Monday 15 April: New timetable with no changes to stops served. Buses run slightly less often during Monday to Friday peaks, no change at other times.',
#   'created': '2019-04-02T10:34:00Z',
#   'lastUpdate': '2019-04-02T10:35:00Z',
#   'affectedRoutes': [],
#   'affectedStops': []},
#  {'$type': 'Tfl.Api.Presentation.Entities.Disruption, Tfl.Api.Presentation.Entities',
#   'category': 'Information',
#   'type': 'lineInfo',
#   'categoryDescription': 'Information',
#   'description': 'Changes to Route 14 from Saturday 20 April: Buses towards Putney Heath will no longer serve Gower Street, south of Grafton Way, Bloomsbury Street or New Oxford Street and will operate via Grafton Way and Tottenham Court Road instead, serving new southbound stops',
#   'created': '2019-04-09T12:20:00Z',
#   'lastUpdate': '2019-04-09T12:20:00Z',
#   'affectedRoutes': [],
#   'affectedStops': []},
#  {'$type': 'Tfl.Api.Presentation.Entities.Disruption, Tfl.Api.Presentation.Entities',
#   'category': 'Information',
#   'type': 'lineInfo',
#   'categoryDescription': 'Information',
#   'description': 'Changes to Route 390 from Saturday 20 April: Buses towards Victoria will no longer serve Gower Street, Bloomsbury Street and New Oxford Street, and will operate via Euston Road (serving the front of University College Hospital) and Tottenham Court Road (serving new southbound stops)',
#   'created': '2019-04-09T12:21:00Z',
#   'lastUpdate': '2019-04-09T12:21:00Z',
#   'affectedRoutes': [],
#   'affectedStops': []},
#  {'$type': 'Tfl.Api.Presentation.Entities.Disruption, Tfl.Api.Presentation.Entities',
#   'category': 'Information',
#   'type': 'lineInfo',
#   'categoryDescription': 'Information',
#   'description': 'Changes to Route N253 from Saturday 20 April: Buses towards Tottenham Court Road will no longer serve Gower Street and Bloomsbury Street, north of New Oxford Street, and will operate via Euston Road (serving the front of University College Hospital), Tottenham Court Road (serving new southbound stops), New Oxford Street and Bloomsbury Street to terminate in St Giles High Street',
#   'created': '2019-04-09T12:22:00Z',
#   'lastUpdate': '2019-04-09T12:22:00Z',
#   'affectedRoutes': [],
#   'affectedStops': []},
#  {'$type': 'Tfl.Api.Presentation.Entities.Disruption, Tfl.Api.Presentation.Entities',
#   'category': 'Information',
#   'type': 'lineInfo',
#   'categoryDescription': 'Information',
#   'description': 'Changes to Route N279 from Saturday 20 April: Buses towards Trafalgar Square will no longer serve Euston Road, Gower Street, Bloomsbury Street and New Oxford Street, and will operate via Tottenham Court Road (serving new southbound stops)',
#   'created': '2019-04-09T12:24:00Z',
#   'lastUpdate': '2019-04-09T12:25:00Z',
#   'affectedRoutes': [],
#   'affectedStops': []},
#  {'$type': 'Tfl.Api.Presentation.Entities.Disruption, Tfl.Api.Presentation.Entities',
#   'category': 'RealTime',
#   'type': 'lineInfo',
#   'categoryDescription': 'RealTime',
#   'description': 'HAMMERSMITH BRIDGE CLOSURE: Routes 33 209 and 485 start and terminate at Castelnau (Lonsdale Road bus stop). Buses are unable to serve stops between Hammersmith Bridge and Hammersmith Bus Station. Route 419 starts and terminates at Lonsdale Road. Buses are unable to serve stops between Kilmington Road and Hammersmith Bus Station. Buses towards Lonsdale Road do not serve Howsman Road and Kilmington Road. Route 72 is diverted between Castelnau and Hammersmith via Lonsdale Road, Mortlake High Street and Chiswick Bridge.',
#   'created': '2019-04-10T17:33:00Z',
#   'lastUpdate': '2019-04-15T08:51:00Z',
#   'affectedRoutes': [],
#   'affectedStops': []},
#  {'$type': 'Tfl.Api.Presentation.Entities.Disruption, Tfl.Api.Presentation.Entities',
#   'category': 'RealTime',
#   'type': 'lineInfo',
#   'categoryDescription': 'RealTime',
#   'description': "HAMMERSMITH BRIDGE CLOSURE: Route 72 is revised to operate between Roehampton, Bessborough Road and Shepherds Bush Green only and is diverted between Hammersmith Bridge Road and Castlenau via Great West Road, Burlington Lane, Alexandra Avenue, Great Chertsey Road, Clifford Avenue, Mortlake High Street and Lonsdale Road due to the closure of Hammersmith Bridge. Bus stop named 'Hammersmith Bridge' is not served in both directions. During the morning and evening peak buses can suffer delays of up to an hour, please allow extra time for your journey. For Du Cane Road and East Acton, please use Route 283 connections, or Route 220 for Wood Lane. A limited overnight service will operate each night beyond Shepherds Bush Green to East Acton, between 0130 and 0430 northbound (times at Shepherds Bush Green) and between 0035 and 0330 southbound (times at East Acton).",
#   'created': '2019-04-10T17:42:00Z',
#   'lastUpdate': '2019-04-18T15:55:00Z',
#   'affectedRoutes': [],
#   'affectedStops': []},
#  {'$type': 'Tfl.Api.Presentation.Entities.Disruption, Tfl.Api.Presentation.Entities',
#   'category': 'Information',
#   'type': 'lineInfo',
#   'categoryDescription': 'Information',
#   'description': 'Changes to buses at Tottenham Court Road from Saturday 20 April: Route 14: Buses towards Putney Heath will no longer serve Gower Street, south of Grafton Way, Bloomsbury Street or New Oxford Street and will operate via Grafton Way and Tottenham Court Road instead, serving new southbound stops',
#   'created': '2019-04-18T15:40:00Z',
#   'lastUpdate': '2019-04-18T15:41:00Z',
#   'affectedRoutes': [],
#   'affectedStops': []},
#  {'$type': 'Tfl.Api.Presentation.Entities.Disruption, Tfl.Api.Presentation.Entities',
#   'category': 'Information',
#   'type': 'lineInfo',
#   'categoryDescription': 'Information',
#   'description': 'Changes to buses at Tottenham Court Road from Saturday 20 April: Routes 19 and N19: Buses towards Battersea Bridge, South Side / Clapham Junction are revised to operate between New Oxford Street and Cambridge Circus via St Giles High Street, Denmark Street and Charing Cross Road instead of Shaftesbury Avenue',
#   'created': '2019-04-18T15:41:00Z',
#   'lastUpdate': '2019-04-18T15:42:00Z',
#   'affectedRoutes': [],
#   'affectedStops': []},
#  {'$type': 'Tfl.Api.Presentation.Entities.Disruption, Tfl.Api.Presentation.Entities',
#   'category': 'Information',
#   'type': 'lineInfo',
#   'categoryDescription': 'Information',
#   'description': 'Changes to buses at Tottenham Court Road from Saturday 20 April: Route 24: Buses towards Pimlico are revised to operate between Warren Street Station and Charing Cross Road via Tottenham Court Road instead of Gower Street, Bloomsbury Street, St Giles High Street and Denmark Street',
#   'created': '2019-04-18T15:42:00Z',
#   'lastUpdate': '2019-04-18T15:43:00Z',
#   'affectedRoutes': [],
#   'affectedStops': []},
#  {'$type': 'Tfl.Api.Presentation.Entities.Disruption, Tfl.Api.Presentation.Entities',
#   'category': 'Information',
#   'type': 'lineInfo',
#   'categoryDescription': 'Information',
#   'description': 'Changes to buses at Tottenham Court Road from Saturday 20 April: Routes 29 and N29: Buses towards Trafalgar Square are revised to operate between Warren Street Station and Charing Cross Road via Tottenham Court Road instead of Gower Street, Bloomsbury Street, St Giles High Street and Denmark Street',
#   'created': '2019-04-18T15:43:00Z',
#   'lastUpdate': '2019-04-18T15:43:00Z',
#   'affectedRoutes': [],
#   'affectedStops': []},
#  {'$type': 'Tfl.Api.Presentation.Entities.Disruption, Tfl.Api.Presentation.Entities',
#   'category': 'Information',
#   'type': 'lineInfo',
#   'categoryDescription': 'Information',
#   'description': 'Changes to buses at Tottenham Court Road from Saturday 20 April: Routes 73 and N73: Buses towards Oxford Circus are revised to operate between Euston Square Station and Tottenham Court Road Station via University College Hospital and Tottenham Court Road instead of Gower Street, Bloomsbury Street, St Giles High Street and Denmark Street',
#   'created': '2019-04-18T15:44:00Z',
#   'lastUpdate': '2019-04-18T15:45:00Z',
#   'affectedRoutes': [],
#   'affectedStops': []},
#  {'$type': 'Tfl.Api.Presentation.Entities.Disruption, Tfl.Api.Presentation.Entities',
#   'category': 'RealTime',
#   'type': 'lineInfo',
#   'categoryDescription': 'RealTime',
#   'description': 'Routes 117 216 and 290 are diverted in Feltham Road due to road works. Route 117 diverted via Town Tree Road, Convent Road and Feltham Road. Routes 216, 290 diverted one way From Church Road via Town Tree Road and Convent Road.',
#   'created': '2019-04-25T06:57:00Z',
#   'lastUpdate': '2019-04-25T06:58:00Z',
#   'affectedRoutes': [],
#   'affectedStops': []},
#  {'$type': 'Tfl.Api.Presentation.Entities.Disruption, Tfl.Api.Presentation.Entities',
#   'category': 'Information',
#   'type': 'lineInfo',
#   'categoryDescription': 'Information',
#   'description': 'Changes to buses at Tottenham Court Road from Saturday 20 April: Route 134: Buses towards Tottenham Court Road are revised to operate between Warren Street and Tottenham Court Road Station via Tottenham Court Road',
#   'created': '2019-04-18T15:45:00Z',
#   'lastUpdate': '2019-04-18T15:45:00Z',
#   'affectedRoutes': [],
#   'affectedStops': []},
#  {'$type': 'Tfl.Api.Presentation.Entities.Disruption, Tfl.Api.Presentation.Entities',
#   'category': 'Information',
#   'type': 'lineInfo',
#   'categoryDescription': 'Information',
#   'description': 'Changes to buses at Tottenham Court Road from Saturday 20 April: Routes N5 and N20: Buses towards Trafalgar Square are revised to operate between Warren Street Station and Charing Cross Road via Tottenham Court Road instead of Gower Street, Bloomsbury Street and Shaftesbury Avenue',
#   'created': '2019-04-18T15:46:00Z',
#   'lastUpdate': '2019-04-18T15:47:00Z',
#   'affectedRoutes': [],
#   'affectedStops': []},
#  {'$type': 'Tfl.Api.Presentation.Entities.Disruption, Tfl.Api.Presentation.Entities',
#   'category': 'Information',
#   'type': 'lineInfo',
#   'categoryDescription': 'Information',
#   'description': 'Changes to buses at Tottenham Court Road from Saturday 20 April: Routes 38 and N38: Buses towards Victoria are revised to operate between New Oxford Street and Cambridge Circus via St Giles High Street, Denmark Street and Charing Cross Road instead of Shaftesbury Avenue',
#   'created': '2019-04-18T15:47:00Z',
#   'lastUpdate': '2019-04-18T15:48:00Z',
#   'affectedRoutes': [],
#   'affectedStops': []},
#  {'$type': 'Tfl.Api.Presentation.Entities.Disruption, Tfl.Api.Presentation.Entities',
#   'category': 'Information',
#   'type': 'lineInfo',
#   'categoryDescription': 'Information',
#   'description': 'Changes to buses at Tottenham Court Road from Saturday 20 April: Route N41: Buses towards Trafalgar Square are revised to operate between New Oxford Street and Cambridge Circus via St Giles High Street, Denmark Street and Charing Cross Road instead of Shaftesbury Avenue',
#   'created': '2019-04-18T15:49:00Z',
#   'lastUpdate': '2019-04-18T15:49:00Z',
#   'affectedRoutes': [],
#   'affectedStops': []},
#  {'$type': 'Tfl.Api.Presentation.Entities.Disruption, Tfl.Api.Presentation.Entities',
#   'category': 'Information',
#   'type': 'lineInfo',
#   'categoryDescription': 'Information',
#   'description': 'Changes to Route 295 from Saturday 27 April: New timetables with no changes to stops served. Buses run less often during the day on Monday to Saturday, now every 8-9 minutes, no change at other times',
#   'created': '2019-04-18T15:50:00Z',
#   'lastUpdate': '2019-04-18T15:50:00Z',
#   'affectedRoutes': [],
#   'affectedStops': []}]
